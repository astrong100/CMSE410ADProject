# %%
import pandas as pd
import os
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Step 1: Load Kunkle GWAS Data + Data Cleaning/Standardization

# %%
Temp = pd.read_csv("GWASdata.txt", sep = r"\s+")

gwas = pd.read_csv("Kunkle_etal_Stage1_results 1 (1).txt", skiprows = 1,sep = r"\s+")
gwas.columns = Temp.columns
print(gwas.head())
# Out:
#    Chromosome   Position        MarkerName Effect_allele Non_Effect_allele  \
# 0           3  110886586         rs7610760             A                 G
# 1           3  110887310  chr3:110887310:D           CAT                 C
# 2           3  110887920       rs143050383             T                 G
# 3           3  110888751        rs17281053             T                 C
# 4           3  110888869       rs150449154             C                 G
#
#      Beta      SE  Pvalue
# 0 -0.0058  0.0279  0.8351
# 1 -0.0090  0.0276  0.7451
# 2  0.0490  0.1155  0.6718
# 3  0.0213  0.0433  0.6229
# 4  0.1719  0.1614  0.2869

# %%
gwas["MarkerName"].isin(["rs429358"]).any()
#Check if APOE is here
# Out:
# np.True_

# %% [markdown]
# Step 2: Slight Adjustments Because of Weird Data Stuff and then Filtering based on P Value of 5E-8. Some column renaming and identifying the major chromosomes involved in these significant interactions

# %%
gwas.columns = Temp.columns
gwas = pd.concat([gwas, Temp])
print(gwas["Chromosome"].value_counts())
# Out:
# Chromosome
# 1     883510
# 4     841113
# 6     791364
# 3     776137
# 5     750123
# 2     741140
# 7     667314
# 8     640583
# 10    592369
# 11    567610
# 12    548865
# 9     496550
# 13    428339
# 14    376881
# 16    342600
# 18    327651
# 15    324332
# 17    296957
# 20    249652
# 19    249037
# 21    154628
# 22    153541
# Name: count, dtype: int64

# %%
gwas = gwas[gwas["Pvalue"] < 5E-8]
gwas_sig = gwas[["MarkerName", "Chromosome", "Position"]]
gwas_sig.columns = ["SNP", "CHR", "BP"]
gwas_sig["chr"] = "chr" + gwas_sig["CHR"].astype(str)
print(len(gwas_sig))
print(gwas_sig["CHR"].value_counts())
print("Chromosomes that have statistically significant SNPS", gwas_sig["CHR"].unique())
print(gwas_sig["SNP"].isin(["rs429358"]).any())
# Out:
# 1514
# CHR
# 19    790
# 11    526
# 6      79
# 2      65
# 1      23
# 8      21
# 7       6
# 10      3
# 14      1
# Name: count, dtype: int64
# Chromosomes that have statistically significant SNPS [ 6  7  8 10 11 14 19  1  2]
# True
# /tmp/ipykernel_3397089/555377219.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwas_sig["chr"] = "chr" + gwas_sig["CHR"].astype(str)

# %% [markdown]
# Step 2: Convert SNPS to Genomic Intervals (BED Format)

# %%
gwas_sig["start"] = gwas_sig["BP"]
gwas_sig["end"] = gwas_sig["BP"] + 1
snps = gwas_sig[["chr", "start", "end", "SNP"]]

snps.head()
# Out:
# /tmp/ipykernel_3397089/1336155299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwas_sig["start"] = gwas_sig["BP"]
# /tmp/ipykernel_3397089/1336155299.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gwas_sig["end"] = gwas_sig["BP"] + 1
#           chr     start       end              SNP
# 2813223  chr6  32386619  32386620        rs4335021
# 2813362  chr6  32394098  32394099        rs3135348
# 2816863  chr6  32488381  32488382      rs112077796
# 2818991  chr6  32521901  32521902  chr6:32521901:I
# 2819382  chr6  32526951  32526952  chr6:32526951:I

# %%
BIN_SIZE = 5000
snps["bin_start"] = (snps["start"] // BIN_SIZE) * BIN_SIZE
snps["bin_end"] = snps["bin_start"] + BIN_SIZE
# Out:
# /tmp/ipykernel_3397089/3172042562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   snps["bin_start"] = (snps["start"] // BIN_SIZE) * BIN_SIZE

# %%
data_path = "GM12878"
files = os.listdir(data_path)
print(files[:10])
# Out:
# ['chr1_5kb.txt', 'chr2_5kb.txt', 'chr3_5kb.txt', 'chr4_5kb.txt', 'chr6_5kb.txt', 'chr7_5kb.txt', 'chr5_5kb.txt', 'chr14_5kb.txt', 'chr8_5kb.txt', 'chr9_5kb.txt']

# %% [markdown]
# Step 3: Loading in Chromosomal Positional Data. For Loop since they are separated by chromosome

# %%
file_path = os.path.join(data_path, "chr1_5kb.txt")
hic3d = pd.read_csv(file_path, sep = "\t")

for i in range(2,23):
    file_path = os.path.join(data_path, f"chr{i}_5kb.txt")
    temp_df = pd.read_csv(file_path, sep = "\t")
    if i == 21:
        temp_df.columns = hic3d.columns
    hic3d = pd.concat([hic3d, temp_df])
hic3d.tail()
hic3d[["x", "y", "z"]].describe()
# Out:
#                    x              y              z
# count  493083.000000  493083.000000  493083.000000
# mean        0.000035      -0.005211       0.011484
# std         0.279353       0.464171       0.352408
# min        -1.939265      -2.843725      -2.378973
# 25%        -0.069613      -0.049729      -0.040491
# 50%         0.009715       0.001845       0.001318
# 75%         0.073191       0.053759       0.041507
# max         3.243274       2.331901       1.956525

# %%
merged = snps.merge(hic3d, left_on = ["chr", "bin_start"], right_on = ["chr", "start"])
print("SNPs before merge:", len(snps))
print("SNPs after merge:", len(merged))
print(merged.head())
print(merged["SNP"].isin(["rs429358"]).any())
# Out:
# SNPs before merge: 1514
# SNPs after merge: 1511
#     chr   start_x     end_x              SNP  bin_start   bin_end     start_y  \
# 0  chr6  32386619  32386620        rs4335021   32385000  32390000  32385000.0
# 1  chr6  32394098  32394099        rs3135348   32390000  32395000  32390000.0
# 2  chr6  32488381  32488382      rs112077796   32485000  32490000  32485000.0
# 3  chr6  32521901  32521902  chr6:32521901:I   32520000  32525000  32520000.0
# 4  chr6  32526951  32526952  chr6:32526951:I   32525000  32530000  32525000.0
#
#         end_y         x         y         z
# 0  32390000.0 -0.132567 -0.058339  0.055222
# 1  32395000.0 -0.134307 -0.059308  0.054915
# 2  32490000.0 -0.140592 -0.054118  0.044624
# 3  32525000.0 -0.139481 -0.064568  0.050685
# 4  32530000.0 -0.140566 -0.064681  0.050530
# True

# %%
Threshold = 0.05

# %%
'''

interactions = []
for i, snp in merged.iterrows():
    distances = np.sqrt((hic3d["x"] - snp["x"])**2 + (hic3d["y"] - snp["y"])**2 + (hic3d["z"] - snp["z"])**2)
    close_bins = hic3d[distances < Threshold]
    interactions.append(close_bins)
print("Hello")


'''
# Out:
# '\n\ninteractions = []\nfor i, snp in merged.iterrows():\n    distances = np.sqrt((hic3d["x"] - snp["x"])**2 + (hic3d["y"] - snp["y"])**2 + (hic3d["z"] - snp["z"])**2)\n    close_bins = hic3d[distances < Threshold]\n    interactions.append(close_bins)\nprint("Hello")\n\n\n'

# %%
# Check what a reasonable threshold looks like
sample_snp = merged.iloc[0]
dists = np.sqrt((hic3d["x"] - sample_snp["x"])**2 + 
                (hic3d["y"] - sample_snp["y"])**2 + 
                (hic3d["z"] - sample_snp["z"])**2)
print(dists.describe())
print("5th percentile:", np.percentile(dists, 5))
print("1st percentile:", np.percentile(dists, 1))
# Out:
# count    493083.000000
# mean          0.373099
# std           0.548452
# min           0.000000
# 25%           0.137748
# 50%           0.199364
# 75%           0.255622
# max           3.928255
# dtype: float64
# 5th percentile: 0.07630718202902834
# 1st percentile: 0.04600951223470159

# %%
from scipy.spatial import cKDTree

# Build KD-tree for fast spatial lookup
coords = hic3d[["x","y","z"]].values
tree = cKDTree(coords)

# Query neighbors
DIST_THRESHOLD = 0.05  # adjust after checking distribution
interactions = []

GENOMIC_THRESHOLD = 50000  # 50 kb

for _, snp in merged.iterrows():
    snp_coord = [snp["x"], snp["y"], snp["z"]]
    
    idx = tree.query_ball_point(snp_coord, DIST_THRESHOLD)
    close_bins = hic3d.iloc[idx]
    # Apply genomic distance filter
    filtered_bins = close_bins[
        (close_bins["chr"] == snp["chr"]) &
        (abs(close_bins["start"] - snp["bin_start"]) > GENOMIC_THRESHOLD)
    ]
    
    interactions.append(filtered_bins)
print("After spatial filter:", len(close_bins))
print("After genomic filter:", len(filtered_bins))
# Out:
# After spatial filter: 15465
# After genomic filter: 3824

# %%
print(interactions[0])
results = []

for i, df in enumerate(interactions):
    if len(df) == 0:
        continue
    
    temp = df.copy()
    temp["SNP"] = merged.iloc[i]["SNP"]
    temp["snp_bin_start"] = merged.iloc[i]["bin_start"]  # ← add this line
    results.append(temp)

results_df = pd.concat(results, ignore_index=True)
print(results_df.columns)
# Out:
#        chr       start         end         x         y         z
# 5080  chr6  26605000.0  26610000.0 -0.115663 -0.052307  0.010627
# 5079  chr6  26600000.0  26605000.0 -0.116967 -0.051779  0.008924
# 5981  chr6  31150000.0  31155000.0 -0.141271 -0.060244  0.030823
# 5970  chr6  31095000.0  31100000.0 -0.141613 -0.056084  0.026629
# 5971  chr6  31100000.0  31105000.0 -0.142195 -0.057671  0.027992
# ...    ...         ...         ...       ...       ...       ...
# 6973  chr6  36155000.0  36160000.0 -0.095149 -0.034529  0.045116
# 6970  chr6  36140000.0  36145000.0 -0.095257 -0.035316  0.046507
# 6963  chr6  36105000.0  36110000.0 -0.094945 -0.035197  0.045241
# 7288  chr6  37730000.0  37735000.0 -0.103353 -0.021316  0.050186
# 8253  chr6  42555000.0  42560000.0 -0.102934 -0.020099  0.047997
#
# [1591 rows x 6 columns]
# Index(['chr', 'start', 'end', 'x', 'y', 'z', 'SNP', 'snp_bin_start'], dtype='object')

# %%
import pandas as pd

gtf = pd.read_csv(
    "gencode.v49.basic.annotation.gtf.gz",
    sep="\t",
    comment="#",
    header=None
)

# %%
gtf.columns = [
    "chr", "source", "feature", "start", "end",
    "score", "strand", "frame", "attribute"
]

# %%
genes = gtf[gtf["feature"] == "gene"].copy()
print(genes.head())
# Out:
#       chr   source feature  start    end score strand frame  \
# 0    chr1   HAVANA    gene  11121  24894     .      +     .
# 6    chr1   HAVANA    gene  12010  13670     .      +     .
# 14   chr1   HAVANA    gene  14356  30744     .      -     .
# 108  chr1   HAVANA    gene  14696  24886     .      -     .
# 120  chr1  ENSEMBL    gene  17369  17436     .      -     .
#
#                                              attribute
# 0    gene_id "ENSG00000290825.2"; gene_type "lncRNA...
# 6    gene_id "ENSG00000223972.6"; gene_type "transc...
# 14   gene_id "ENSG00000310526.1"; gene_type "lncRNA...
# 108  gene_id "ENSG00000227232.6"; gene_type "transc...
# 120  gene_id "ENSG00000278267.1"; gene_type "miRNA"...

# %%
import re

def extract_gene_name(attr):
    match = re.search('gene_name "([^"]+)"', attr)
    return match.group(1) if match else None

genes["gene_name"] = genes["attribute"].apply(extract_gene_name)

# %%
genes["chr"].unique()[:21]
genes.columns
# Out:
# Index(['chr', 'source', 'feature', 'start', 'end', 'score', 'strand', 'frame',
#        'attribute', 'gene_name'],
#       dtype='object')

# %%
results_df.head()
# Out:
#     chr       start         end         x         y         z        SNP  \
# 0  chr6  26605000.0  26610000.0 -0.115663 -0.052307  0.010627  rs4335021
# 1  chr6  26600000.0  26605000.0 -0.116967 -0.051779  0.008924  rs4335021
# 2  chr6  31150000.0  31155000.0 -0.141271 -0.060244  0.030823  rs4335021
# 3  chr6  31095000.0  31100000.0 -0.141613 -0.056084  0.026629  rs4335021
# 4  chr6  31100000.0  31105000.0 -0.142195 -0.057671  0.027992  rs4335021
#
#    snp_bin_start
# 0       32385000
# 1       32385000
# 2       32385000
# 3       32385000
# 4       32385000

# %%
# %pip install pyranges
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyranges in ./.local/lib/python3.12/site-packages (0.1.4)
# Requirement already satisfied: pandas in /opt/miniconda3/lib/python3.12/site-packages (from pyranges) (2.3.3)
# Requirement already satisfied: ncls>=0.0.63 in ./.local/lib/python3.12/site-packages (from pyranges) (0.0.70)
# Requirement already satisfied: tabulate in ./.local/lib/python3.12/site-packages (from pyranges) (0.10.0)
# Requirement already satisfied: sorted_nearest>=0.0.33 in ./.local/lib/python3.12/site-packages (from pyranges) (0.0.41)
# Requirement already satisfied: natsort in ./.local/lib/python3.12/site-packages (from pyranges) (8.4.0)
# Requirement already satisfied: numpy in /opt/miniconda3/lib/python3.12/site-packages (from ncls>=0.0.63->pyranges) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/lib/python3.12/site-packages (from pandas->pyranges) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/lib/python3.12/site-packages (from pandas->pyranges) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/lib/python3.12/site-packages (from pandas->pyranges) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->pyranges) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyranges as pr
#Identify Promoter Overlap
bins_pr = pr.PyRanges(results_df.rename(columns={
    "chr": "Chromosome",
    "start": "Start",
    "end": "End"
}))

genes_pr = pr.PyRanges(genes.rename(columns={
    "chr": "Chromosome",
    "start": "Start",
    "end": "End"
}))

gene_hits = bins_pr.join(genes_pr)
gene_list = gene_hits.df["gene_name"].dropna().unique()
print(gene_list)
# Out:
# ['LIN9' 'YBX1P9' 'ENSG00000299722' ... 'ENSG00000300700' 'CYP2T1P' 'MIA']

# %%
set(gene_list) & {"APOE", "TREM2", "APP"}
# Out:
# {'TREM2'}

# %%
# %pip install gprofiler-official
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gprofiler-official in ./.local/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: requests in /opt/miniconda3/lib/python3.12/site-packages (from gprofiler-official) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests->gprofiler-official) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests->gprofiler-official) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.12/site-packages (from requests->gprofiler-official) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests->gprofiler-official) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
gene_list = (
    gene_hits.df["gene_name"]
    .dropna()
    .astype(str)
    .unique()
    .tolist()
)
from gprofiler import GProfiler

gp = GProfiler(return_dataframe=True)

enrich_results = gp.profile(
    organism='hsapiens',
    query=gene_list
)
print("Done")
# Out:
# Done

# %%
print(enrich_results.shape[0])

print(enrich_results.head(100))
sig = enrich_results[enrich_results["significant"] == True]
sig = sig.sort_values("p_value")
# Out:
# 128
#    source      native                                               name  \
# 0   GO:CC  GO:0042611                                MHC protein complex
# 1    KEGG  KEGG:04612                Antigen processing and presentation
# 2   GO:MF  GO:0042605                            peptide antigen binding
# 3   GO:BP  GO:0048002  antigen processing and presentation of peptide...
# 4      WP   WP:WP5346              8p23 1 copy number variation syndrome
# ..    ...         ...                                                ...
# 95   KEGG  KEGG:05416                                  Viral myocarditis
# 96   KEGG  KEGG:04145                                          Phagosome
# 97  GO:CC  GO:0098797                    plasma membrane protein complex
# 98  GO:BP  GO:0001909                    leukocyte mediated cytotoxicity
# 99  GO:MF  GO:0060089                      molecular transducer activity
#
#          p_value  significant  \
# 0   5.640131e-15         True
# 1   4.844628e-11         True
# 2   6.955829e-11         True
# 3   5.282363e-09         True
# 4   1.757818e-08         True
# ..           ...          ...
# 95  1.226289e-02         True
# 96  1.233411e-02         True
# 97  1.238500e-02         True
# 98  1.289860e-02         True
# 99  1.403834e-02         True
#
#                                           description  term_size  query_size  \
# 0   "A transmembrane protein complex composed of a...         24        2046
# 1                 Antigen processing and presentation         69         845
# 2   "Binding to an antigen peptide." [GOC:add, GOC...         42        1864
# 3   "The process in which an antigen-presenting ce...         68        1936
# 4               8p23 1 copy number variation syndrome         54         881
# ..                                                ...        ...         ...
# 95                                  Viral myocarditis         63         845
# 96                                          Phagosome        147         845
# 97  "Any protein complex that is part of the plasm...        725        2046
# 98  "The directed killing of a target cell by a le...        143        1936
# 99  "A compound molecular function in which an eff...       2053        1864
#
#     intersection_size  effective_domain_size  precision    recall    query  \
# 0                  20                  22149   0.009775  0.833333  query_1
# 1                  30                   8484   0.035503  0.434783  query_1
# 2                  23                  20246   0.012339  0.547619  query_1
# 3                  28                  21026   0.014463  0.411765  query_1
# 4                  24                   8752   0.027242  0.444444  query_1
# ..                ...                    ...        ...       ...      ...
# 95                 17                   8484   0.020118  0.269841  query_1
# 96                 30                   8484   0.035503  0.204082  query_1
# 97                100                  22149   0.048876  0.137931  query_1
# 98                 31                  21026   0.016012  0.216783  query_1
# 99                242                  20246   0.129828  0.117876  query_1
#
#                      parents
# 0               [GO:0098797]
# 1               [KEGG:00000]
# 2   [GO:0003823, GO:0042277]
# 3               [GO:0019882]
# 4                [WP:000000]
# ..                       ...
# 95              [KEGG:00000]
# 96              [KEGG:00000]
# 97  [GO:0005886, GO:0098796]
# 98  [GO:0001906, GO:0002443]
# 99              [GO:0003674]
#
# [100 rows x 14 columns]

# %%
import matplotlib.pyplot as plt

top = sig.head(20)

plt.barh(top["name"], -np.log10(top["p_value"]))
plt.xlabel("-log10(p-value)")
plt.title("Top Enriched Pathways")
plt.gca().invert_yaxis()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
top = sig.head(20).copy()
top = top[top["name"] != "response to stimulus"]
top = top.sort_values("intersection_size", ascending=False)
# Map p-values to colors (red = most significant, blue = least)
norm = mcolors.Normalize(vmin=top["p_value"].min(), vmax=top["p_value"].max())
colors = cm.RdBu(norm(top["p_value"]))

fig, ax = plt.subplots(figsize=(10, 8))
bars = ax.barh(top["name"], top["intersection_size"], color=colors)

ax.set_xlabel("Number of Genes in Pathway")
ax.set_ylabel("Pathway")
ax.set_title("Top Enriched Pathways")
ax.invert_yaxis()

sm = cm.ScalarMappable(cmap="RdBu", norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax)
cbar.set_label("p-value")

plt.tight_layout()
plt.show()

# %%
results_df["genomic_distance"] = abs(
    results_df["start"] - results_df["snp_bin_start"]
)

ax = results_df["genomic_distance"].hist(bins=50)
ax.set_xlabel("Genomic Distance (bp)")
ax.set_ylabel("Number of Interacting Bin Pairs")
ax.set_title("Distribution of Genomic Distances for Long-Range Chromatin Interactions")
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{int(x):,}"))
plt.tight_layout()
plt.show()
